# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
from scipy import stats
from scipy.stats import ttest_ind, f_oneway, chi2_contingency, poisson, norm

# Reproducibility
np.random.seed(42)

# Plot styling
plt.rcParams['figure.figsize'] = (12, 5)
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False
sns.set_palette('husl')

print('Libraries loaded successfully.')
# Out:
# Libraries loaded successfully.

# %%
df=pd.read_csv('../data/insurance_cleaned.csv')
df.columns
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_12196\3325133922.py:1: DtypeWarning: Columns (0: CapitalOutstanding, 1: CrossBorder) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('../data/insurance_cleaned.csv')
# Index(['UnderwrittenCoverID', 'PolicyID', 'TransactionMonth',
#        'IsVATRegistered', 'Citizenship', 'LegalType', 'Title', 'Language',
#        'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province',
#        'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode',
#        'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders',
#        'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors',
#        'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser',
#        'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff',
#        'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet',
#        'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm',
# ...

# %%
print(f'Dataset shape: {df.shape}')
# df.head(10)
# df['ClaimFrequency']
df.columns
# Out:
# Dataset shape: (1000098, 52)
# Index(['UnderwrittenCoverID', 'PolicyID', 'TransactionMonth',
#        'IsVATRegistered', 'Citizenship', 'LegalType', 'Title', 'Language',
#        'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province',
#        'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode',
#        'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders',
#        'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors',
#        'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser',
#        'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff',
#        'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet',
#        'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm',
#        'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section',
#        'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium',
#        'TotalClaims'],
#       dtype='str')

# %%
import sys
import os

sys.path.append(os.path.abspath("../src"))

from hypothesis_tests import HypothesisTesting

# %%
province_test = HypothesisTesting(
    df=df,
    kpi="TotalClaims",
    group_column="Province",
    group_a="Gauteng",
    group_b="Western Cape"
)
province_test.run_hypothesis_test(
    "There are no risk differences across provinces."
)
# Out:
# ...
# HYPOTHESIS TESTING REPORT
# ...
#
# NULL HYPOTHESIS
# ------------------------------------------------------------
# H₀: There are no risk differences across provinces.
#
# ...
# FREQUENCY TEST
# ...
#
# Group Column: Province
# KPI: TotalClaims
#
# Gauteng: 0.0034
# Western Cape: 0.0022
#
# P-value: 0.0000
# Reject H₀
# There is a statistically significant difference.
#
# ...
# SEVERITY / MEAN DIFFERENCE TEST
# ...
#
# Gauteng Mean: 22243.878395705604
# Western Cape Mean: 28095.849880512094
#
# P-value: 0.0306
# Reject H₀
# Significant mean difference detected.

# %%
zipcode_risk_test = HypothesisTesting(
    df=df,
    kpi="TotalClaims",
    group_column="PostalCode",
    group_a=1459,
    group_b=7493
)

zipcode_risk_test.run_hypothesis_test(
    "There are no risk differences between zip codes."
)
# Out:
# ...
# HYPOTHESIS TESTING REPORT
# ...
#
# NULL HYPOTHESIS
# ------------------------------------------------------------
# H₀: There are no risk differences between zip codes.
#
# ...
# FREQUENCY TEST
# ...
#
# Group Column: PostalCode
# KPI: TotalClaims
#
# 1459: 0.0000
# 7493: 0.0013
#
# P-value: 0.9215
# Fail to Reject H₀
# No statistically significant difference found.
#
# ...
# SEVERITY / MEAN DIFFERENCE TEST
# ...
#
# 1459 Mean: nan
# 7493 Mean: 15797.464912280682
#
# Severity test could not be performed.
# Severity test cannot be performed because one group has no claims.

# %%
df['Margin'] = df['TotalPremium'] - df['TotalClaims']
margin_test = HypothesisTesting(
    df=df,
    kpi="Margin",
    group_column="PostalCode",
    group_a=1459,
    group_b=7493
)

margin_test.run_hypothesis_test(
    "There is no significant margin difference between zip codes."
)
# Out:
# ...
# HYPOTHESIS TESTING REPORT
# ...
#
# NULL HYPOTHESIS
# ------------------------------------------------------------
# H₀: There is no significant margin difference between zip codes.
#
# ...
# FREQUENCY TEST
# ...
#
# Group Column: PostalCode
# KPI: Margin
#
# 1459: 0.6447
# 7493: 0.6621
#
# P-value: 0.4695
# Fail to Reject H₀
# No statistically significant difference found.
#
# ...
# SEVERITY / MEAN DIFFERENCE TEST
# ...
#
# 1459 Mean: 114.5749402420657
# 7493 Mean: 94.058827282429
#
# P-value: 0.0739
# Fail to Reject H₀
# No significant mean difference detected.

# %%
gender_test = HypothesisTesting(
    df=df,
    kpi="TotalClaims",
    group_column="Gender",
    group_a="Female",
    group_b="Male"
)

gender_test.run_hypothesis_test(
    "There is no significant risk difference between Women and Men."
)
# Out:
# ...
# HYPOTHESIS TESTING REPORT
# ...
#
# NULL HYPOTHESIS
# ------------------------------------------------------------
# H₀: There is no significant risk difference between Women and Men.
#
# ...
# FREQUENCY TEST
# ...
#
# Group Column: Gender
# KPI: TotalClaims
#
# Female: 0.0020
# Male: 0.0021
#
# P-value: 0.9966
# Fail to Reject H₀
# No statistically significant difference found.
#
# ...
# SEVERITY / MEAN DIFFERENCE TEST
# ...
#
# Female Mean: 17874.721303258153
# Male Mean: 16243.377581073904
#
# P-value: 0.7575
# Fail to Reject H₀
# No significant mean difference detected.
